# %%
import numpy as np
from scipy.ndimage import correlate
import math
from skimage.segmentation import slic, quickshift, watershed
from skimage.segmentation import mark_boundaries, find_boundaries, felzenszwalb
from skimage import img_as_ubyte
from skimage.future import graph

from my_imread import my_imread
from my_fspecial import my_fspecial

import os, sys
import time
import cv2
from matplotlib import pyplot as plt

from IPython.display import clear_output

# %%
def LSC_superpixel(I, nseg, name):
    
    superpixelNum = nseg
    
    ratio = 0.075
    
    size = int(math.sqrt(((I.shape[0]*I.shape[1]) / nseg)))

    superpixelLSC = cv2.ximgproc.createSuperpixelLSC(
            I,
            region_size=size,
            ratio=0.075)
    
    
    start=time.time()
    superpixelLSC.iterate()
    superpixelLSC.enforceLabelConnectivity(min_element_size=25)
    segments = superpixelLSC.getLabels()
    end = time.time()
    
    elapsed_time = (end-start)
    
    superpixel_image = mark_boundaries(I, segments) *255
    
    cv2.imwrite(os.path.join('results', 'LSC', name+'_'+str(nseg)+'.png'), superpixel_image)
    
    return segments, elapsed_time



def SLIC_superpixel(I, nseg, name):
    
    start=time.time()
    segments = slic(I, n_segments=nseg)
    end = time.time()
    
    elapsed_time = (end-start)

    superpixel_image = mark_boundaries(I, segments)*255

    cv2.imwrite(os.path.join('results', 'SLIC', name+'_'+str(nseg)+'.png'), superpixel_image)
        
    return segments, elapsed_time



def NormCut_superpixel(I, nseg, name):
    
    start=time.time()
    labels1 = slic(I,  n_segments=nseg)
    
    g = graph.rag_mean_color(I, labels1, mode='similarity')
    
    segments = graph.cut_normalized(labels1, g)
    end = time.time()
    
    elapsed_time = (end-start)
    
    
    superpixel_image = mark_boundaries(I, segments)*255
    
    cv2.imwrite(os.path.join('results', 'NCUT', name+'_'+str(nseg)+'.png'), superpixel_image)
    
    return segments, elapsed_time
    
            
def FH_superpixel(I, nseg, name):
    
    start=time.time()
    segments = felzenszwalb(img, min_size= int(47000 / nseg))  ### by collecting multile samples of segmentation 
                                                                ## for different min_size argument, I found that the 
                                                                ## no. of segments is approximaately N/min_size where
                                                                ## N is between 42000 and 52000... hence I take avg. of
                                                                ## 47000... nseg is the desired number of segments
    end = time.time()
    
    elapsed_time = (end-start)
    
    superpixel_image = mark_boundaries(I, segments)*255
    
    cv2.imwrite(os.path.join('results', 'FH', name+'_'+str(nseg)+'.png'), superpixel_image)
    
    return segments, elapsed_time



def SEEDS_superpixel(I, nseg, name):
    
    I_new = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    height,width,channels = I_new.shape
    
    superpixelNum = nseg
    
    start=time.time()
    seeds = cv2.ximgproc.createSuperpixelSEEDS(width, height, channels, superpixelNum, 4, 2, 5)
    seeds.iterate(I_new)
    segments = seeds.getLabels()
    end = time.time()
    
    elapsed_time = (end-start)
    
    superpixel_image = mark_boundaries(I, segments) *255
    
    cv2.imwrite(os.path.join('results', 'SEEDS', name+'_'+str(nseg)+'.png'), superpixel_image)
    
    return segments, elapsed_time

# %% [markdown]
# # Run and Record

# %%
def calc_UE(l, GT, UE):

    temp = np.array(l)

    overlap_with_GT = [[] for x in range(temp.max()+1)]

    row, col = temp.shape
    
    for r in range(row):
        for c in range(col):
            overlap_with_GT[l[r,c]].append(GT[r,c])
        
    ue = 0
        
    for i in range(len(overlap_with_GT)):
        gt = np.array(overlap_with_GT[i])
        if len(np.unique(gt)) > 1:
            ue += 1
        
    UE.append(ue/(temp.max()))
    
    return UE


def calc_BR(l, GT, BR):
    
    segBounds = find_boundaries(l, mode='inner').astype(np.uint8)
    GTBounds = find_boundaries(GT, mode='inner').astype(np.uint8)
    
    rows, cols = GTBounds.shape
    
    total_GT_bound_pixels = 0
    recalled_pixels = 0
    
    for r in range(rows):
        for c in range(cols):
            
            if GTBounds[r,c] == True:
                
                total_GT_bound_pixels += 1  #### this is a boundary pixel
                
                stop_check = 0
                
                for i in range(-2, 3):
                    if r+i >=0 and r+i < rows:
                        for j in range(-2, 3):
                            if c+j >=0 and c+j < cols:
                                if segBounds[r+i, c+j] == True: ## Ground Truth boundary pixel is close to 
                                                                ## atleast one segment boundary
                                    recalled_pixels += 1
                                    stop_check = 1
                                    break
                                
                    if stop_check:
                        break
    
    BR.append(recalled_pixels/total_GT_bound_pixels)
    
    return BR

# %%
def run_LSC(I, name, n_superpixels, GT):

    labels = []
    time = []
    UE = []
    BR = []
    
    for nseg in n_superpixels:
        
        l, t = LSC_superpixel(I, nseg, name)
        
        labels.append(l)
        time.append(t)
        
        ####################### Undersegmentation Error #########################             
        UE = calc_UE(l, GT, UE)
        BR = calc_BR(l, GT, BR)
        
        
    return labels, time, UE, BR
        
        

def run_SLIC(I, name, n_superpixels, GT):

    labels = []
    time = []
    UE = []
    BR = []
    
    for nseg in n_superpixels:
        
        l, t = SLIC_superpixel(I, nseg, name)
        
        labels.append(l)
        time.append(t)

        ####################### Undersegmentation Error #########################             
        UE = calc_UE(l, GT, UE)
        BR = calc_BR(l, GT, BR)
        
    return labels, time, UE, BR
    
    
    
def run_NormCut(I, name, n_superpixels, GT):

    labels = []
    time = []
    UE = []
    BR = []
    
    for nseg in n_superpixels:
        
        l, t = NormCut_superpixel(I, nseg, name)
        
        labels.append(l)
        time.append(t) 
        
        ####################### Undersegmentation Error #########################             
        UE = calc_UE(l, GT, UE)
        BR = calc_BR(l, GT, BR)
        
    return labels, time, UE, BR
    
    
    
def run_FH(I, name, n_superpixels, GT):

    labels = []
    time = []
    UE = []
    BR = []
    
    for nseg in n_superpixels:
        
        l, t = FH_superpixel(I, nseg, name)
        
        labels.append(l)
        time.append(t) 
        
        ####################### Undersegmentation Error #########################             
        UE = calc_UE(l, GT, UE)
        BR = calc_BR(l, GT, BR)
        
    return labels, time, UE, BR  


def run_SEEDS(I, name, n_superpixels, GT):
    
    labels = []
    time = []
    UE = []
    BR = []
    
    for nseg in n_superpixels:
        
        l, t = SEEDS_superpixel(I, nseg, name)
        
        labels.append(l)
        time.append(t) 
        
        ####################### Undersegmentation Error #########################             
        UE = calc_UE(l, GT, UE)
        BR = calc_BR(l, GT, BR)
        
    return labels, time, UE, BR

# %% [markdown]
# # MAIN

# %%
import glob, re

RGBimages = list(sorted(glob.glob(os.path.join('images', '*.*'))))


collect_runtime_LSC = []
collect_UE_LSC = []
collect_BR_LSC = []

collect_runtime_SLIC = []
collect_UE_SLIC = []
collect_BR_SLIC = []

collect_runtime_NormCut = []
collect_UE_NormCut = []
collect_BR_NormCut = []

collect_runtime_FH = []
collect_UE_FH = []
collect_BR_FH = []

collect_runtime_SEEDS = []
collect_UE_SEEDS = []
collect_BR_SEEDS = []


doLSC = 1
doSLIC = 1
doNormCut = 1
doFH = 1
doSEEDS = 1


ln = len(RGBimages)

#ln = 100

print("Number of Images: ", ln, '\n')


global_start = time.time()

for im in range(ln): 
        
    ImageName, _ = os.path.splitext(os.path.basename(RGBimages[im]))
    
    print('Count; ', im, ' Image Name: ', ImageName)

        
    img = my_imread(os.path.join('images', ImageName + '.jpg'))
    

    human_labels = np.zeros((img.shape[0], img.shape[1]), dtype=int)
    
    segfile = os.path.join('BSDS300-human','BSDS300','human','common', ImageName+'.seg')
    
    label_list = []
    
    with open(segfile) as f:
        for line in f:
            lin = line.split(' ')
            if not re.match("^[a-zA-Z]*$", lin[0]):  #### it's a line containing labels
                lin = [int(x) for x in lin]
                label_list.append(lin)
    
    
    for i in range(len(label_list)):
        
        lbl = label_list[i][0]
        row = label_list[i][1]
        from_col = label_list[i][2]
        to_col = label_list[i][3]
        
        for col in range(from_col, to_col+1):
            human_labels[row][col] = lbl

     

    
    
    ######################################################################
    # At this point, we have the ground truth segmentation for the image 
    # as 'human_labels'. Now, we will obtain segmentation from various 
    # algortihms and compare...
    ######################################################################

    
    ### apply gaussian 
    gaus = my_fspecial('gaussian', 3)
    
    I = correlate(img.astype(np.float64),
                gaus.reshape(gaus.shape[0], gaus.shape[1], 1),
                mode="constant").round().astype(np.uint8)
    
    print(I.shape)
    
            
    human_superpixel_image = mark_boundaries(I, human_labels) *255
    cv2.imwrite(os.path.join('results', 'GroundTruth', ImageName+'.png'), human_superpixel_image)
    
        
    n_superpixels = range(50, 550, 50)
    
    try:
        if doLSC:
            print('running LSC')
            LSC_labels, LSC_times, LSC_UE, LSC_BR = run_LSC(I, ImageName, n_superpixels, human_labels)

        if doSLIC:
            print('running SLIC')
            SLIC_labels, SLIC_times, SLIC_UE, SLIC_BR = run_SLIC(I, ImageName, n_superpixels, human_labels)

        if doNormCut:
            print('running NormCut')
            NormCut_labels, NormCut_times, NormCut_UE, NormCut_BR = run_NormCut(I, ImageName, n_superpixels, human_labels)
            
        if doFH:
            print('running FH')
            FH_labels, FH_times, FH_UE, FH_BR = run_FH(I, ImageName, n_superpixels, human_labels)

        if doSEEDS:
            print('running SEEDS')
            SEEDS_labels, SEEDS_times, SEEDS_UE, SEEDS_BR = run_SEEDS(I, ImageName, n_superpixels, human_labels)          
    
    except:
            print("Failed for image# : ", im, ' ', ImageName, '\n')
            continue

    
    global_end = time.time()

            
    print('\nTotal Elapsed Time so far...: ', (global_end-global_start)/60, ' min.')
    print('\n')

        
    collect_runtime_LSC.append(LSC_times)
    collect_UE_LSC.append(LSC_UE)
    collect_BR_LSC.append(LSC_BR)
    
    collect_runtime_SLIC.append(SLIC_times)
    collect_UE_SLIC.append(SLIC_UE)
    collect_BR_SLIC.append(SLIC_BR)

    collect_runtime_NormCut.append(NormCut_times)
    collect_UE_NormCut.append(NormCut_UE)
    collect_BR_NormCut.append(NormCut_BR)
    
    collect_runtime_FH.append(FH_times)
    collect_UE_FH.append(FH_UE)
    collect_BR_FH.append(FH_BR)
    
    collect_runtime_SEEDS.append(SEEDS_times)
    collect_UE_SEEDS.append(SEEDS_UE)
    collect_BR_SEEDS.append(SEEDS_BR)
# Out:
# Number of Images:  300
#
# Count;  0  Image Name:  100075
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  1.5547455112139383  min.
#
#
# Count;  1  Image Name:  100080
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  2.971379498640696  min.
#
#
# Count;  2  Image Name:  100098
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  4.808143599828084  min.
#
#
# Count;  3  Image Name:  101085
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  6.505946326255798  min.
#
#
# Count;  4  Image Name:  101087
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  7.99601624806722  min.
#
#
# Count;  5  Image Name:  102061
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  9.401717980702719  min.
#
#
# Count;  6  Image Name:  103041
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  11.025941606362661  min.
#
#
# Count;  7  Image Name:  103070
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  12.699571843942007  min.
#
#
# Count;  8  Image Name:  104022
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  14.124817721048991  min.
#
#
# Count;  9  Image Name:  105019
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  15.436125687758128  min.
#
#
# Count;  10  Image Name:  105025
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  16.871755627791085  min.
#
#
# Count;  11  Image Name:  105053
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  18.20576416651408  min.
#
#
# Count;  12  Image Name:  106020
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  19.651531040668488  min.
#
#
# Count;  13  Image Name:  106024
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  21.000986337661743  min.
#
#
# Count;  14  Image Name:  106025
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  22.343988049030305  min.
#
#
# Count;  15  Image Name:  108005
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  23.985621078809103  min.
#
#
# Count;  16  Image Name:  108041
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  25.660737903912864  min.
#
#
# Count;  17  Image Name:  108070
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  27.05373659133911  min.
#
#
# Count;  18  Image Name:  108073
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  28.38040415843328  min.
#
#
# Count;  19  Image Name:  108082
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  29.82424951394399  min.
#
#
# Count;  20  Image Name:  109034
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  31.250355048974356  min.
#
#
# Count;  21  Image Name:  109053
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# C:\Users\SHUBHAM007\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\ipykernel\__main__.py:20: RuntimeWarning: divide by zero encountered in longlong_scalars
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  32.677632602055866  min.
#
#
# Count;  22  Image Name:  112082
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  34.124769401550296  min.
#
#
# Count;  23  Image Name:  113009
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  35.562250367800395  min.
#
#
# Count;  24  Image Name:  113016
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  36.95910028219223  min.
#
#
# Count;  25  Image Name:  113044
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  38.327830171585084  min.
#
#
# Count;  26  Image Name:  117054
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  39.826641245683035  min.
#
#
# Count;  27  Image Name:  118020
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  41.379246175289154  min.
#
#
# Count;  28  Image Name:  118035
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  42.739707215627035  min.
#
#
# Count;  29  Image Name:  119082
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  44.4469110528628  min.
#
#
# Count;  30  Image Name:  12003
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  45.92186288833618  min.
#
#
# Count;  31  Image Name:  12074
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  47.55178054173788  min.
#
#
# Count;  32  Image Name:  12084
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  49.05022160212199  min.
#
#
# Count;  33  Image Name:  122048
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  50.590574729442594  min.
#
#
# Count;  34  Image Name:  123074
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  51.999617890516916  min.
#
#
# Count;  35  Image Name:  124084
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  53.564445690313974  min.
#
#
# Count;  36  Image Name:  126007
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  54.948012320200604  min.
#
#
# Count;  37  Image Name:  126039
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  56.671740396817526  min.
#
#
# Count;  38  Image Name:  130026
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  58.12084953784942  min.
#
#
# Count;  39  Image Name:  130034
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  59.39056056340535  min.
#
#
# Count;  40  Image Name:  134008
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  60.63018789291382  min.
#
#
# Count;  41  Image Name:  134035
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# Failed for image# :  41   134035
#
# Count;  42  Image Name:  134052
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  62.84498137633006  min.
#
#
# Count;  43  Image Name:  135037
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  64.34790039459864  min.
#
#
# Count;  44  Image Name:  135069
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  65.56217892169953  min.
#
#
# Count;  45  Image Name:  138032
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  67.23708748022715  min.
#
#
# Count;  46  Image Name:  138078
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  68.59337346156438  min.
#
#
# Count;  47  Image Name:  140055
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  70.07766691446304  min.
#
#
# Count;  48  Image Name:  140075
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  72.04817667802175  min.
#
#
# Count;  49  Image Name:  14037
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  73.39937664667765  min.
#
#
# Count;  50  Image Name:  143090
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  74.75189615488053  min.
#
#
# Count;  51  Image Name:  144067
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  76.13925209840139  min.
#
#
# Count;  52  Image Name:  145014
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  77.76690565745035  min.
#
#
# Count;  53  Image Name:  145053
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  79.34196920792262  min.
#
#
# Count;  54  Image Name:  145086
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  80.73109109799067  min.
#
#
# Count;  55  Image Name:  147021
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  82.02043873469034  min.
#
#
# Count;  56  Image Name:  147062
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  83.35818292299906  min.
#
#
# Count;  57  Image Name:  147091
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  84.73908013105392  min.
#
#
# Count;  58  Image Name:  148026
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  86.13565223614374  min.
#
#
# Count;  59  Image Name:  148089
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  87.62660847504934  min.
#
#
# Count;  60  Image Name:  15004
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  89.76667924324671  min.
#
#
# Count;  61  Image Name:  15088
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  91.08968573013941  min.
#
#
# Count;  62  Image Name:  151087
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  92.67051305770875  min.
#
#
# Count;  63  Image Name:  153077
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  94.29386941194534  min.
#
#
# Count;  64  Image Name:  153093
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# Failed for image# :  64   153093
#
# Count;  65  Image Name:  155060
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  96.66568187475204  min.
#
#
# Count;  66  Image Name:  156065
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  98.10919428666433  min.
#
#
# Count;  67  Image Name:  156079
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  99.6606417218844  min.
#
#
# Count;  68  Image Name:  157036
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  101.2521279613177  min.
#
#
# Count;  69  Image Name:  157055
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  103.06602255900701  min.
#
#
# Count;  70  Image Name:  159008
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  104.6506585597992  min.
#
#
# Count;  71  Image Name:  159029
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  106.32563004493713  min.
#
#
# Count;  72  Image Name:  159045
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  107.91888362963995  min.
#
#
# Count;  73  Image Name:  159091
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  109.39202446142832  min.
#
#
# Count;  74  Image Name:  160068
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  110.78241352240245  min.
#
#
# Count;  75  Image Name:  16052
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  112.53177603880565  min.
#
#
# Count;  76  Image Name:  16077
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  114.13356736898422  min.
#
#
# Count;  77  Image Name:  161062
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  115.44507430791855  min.
#
#
# Count;  78  Image Name:  163014
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  116.86170235872268  min.
#
#
# Count;  79  Image Name:  163062
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  118.2478877822558  min.
#
#
# Count;  80  Image Name:  163085
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  119.71359074115753  min.
#
#
# Count;  81  Image Name:  164074
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  121.00478737751642  min.
#
#
# Count;  82  Image Name:  166081
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  122.43056664466857  min.
#
#
# Count;  83  Image Name:  167062
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  123.63972465991974  min.
#
#
# Count;  84  Image Name:  167083
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  124.9422403216362  min.
#
#
# Count;  85  Image Name:  169012
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  126.4880265235901  min.
#
#
# Count;  86  Image Name:  170054
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  128.21925084988277  min.
#
#
# Count;  87  Image Name:  170057
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  129.71292940378189  min.
#
#
# Count;  88  Image Name:  172032
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  131.036948009332  min.
#
#
# Count;  89  Image Name:  173036
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  132.3951400756836  min.
#
#
# Count;  90  Image Name:  175032
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  133.84087240695953  min.
#
#
# Count;  91  Image Name:  175043
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  135.40191756486894  min.
#
#
# Count;  92  Image Name:  176019
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  136.88600514332452  min.
#
#
# Count;  93  Image Name:  176035
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  138.3242582877477  min.
#
#
# Count;  94  Image Name:  176039
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  139.74019449154537  min.
#
#
# Count;  95  Image Name:  178054
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  141.07133972644806  min.
#
#
# Count;  96  Image Name:  181018
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  142.55177618662518  min.
#
#
# Count;  97  Image Name:  181079
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  143.94688310225806  min.
#
#
# Count;  98  Image Name:  181091
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  145.3338141600291  min.
#
#
# Count;  99  Image Name:  182053
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  146.82150629758834  min.
#
#
# Count;  100  Image Name:  183055
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  148.14653971195222  min.
#
#
# Count;  101  Image Name:  183087
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  149.52299912373226  min.
#
#
# Count;  102  Image Name:  187003
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  151.1018823583921  min.
#
#
# Count;  103  Image Name:  187029
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  152.54350952307382  min.
#
#
# Count;  104  Image Name:  187039
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  153.92729498942694  min.
#
#
# Count;  105  Image Name:  187071
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  155.43226344188054  min.
#
#
# Count;  106  Image Name:  187083
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  156.75592829783758  min.
#
#
# Count;  107  Image Name:  188005
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  158.14662542740504  min.
#
#
# Count;  108  Image Name:  188063
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  159.45042379697165  min.
#
#
# Count;  109  Image Name:  188091
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  160.74187385638555  min.
#
#
# Count;  110  Image Name:  189003
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# Failed for image# :  110   189003
#
# Count;  111  Image Name:  189011
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  162.99766383568445  min.
#
#
# Count;  112  Image Name:  189080
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  164.34693560997644  min.
#
#
# Count;  113  Image Name:  19021
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  165.9273735165596  min.
#
#
# Count;  114  Image Name:  196015
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  167.34259187777837  min.
#
#
# Count;  115  Image Name:  196073
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  168.6046765168508  min.
#
#
# Count;  116  Image Name:  197017
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  169.9892991264661  min.
#
#
# Count;  117  Image Name:  198004
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  171.38431207338968  min.
#
#
# Count;  118  Image Name:  198023
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# Failed for image# :  118   198023
#
# Count;  119  Image Name:  198054
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  173.66967379252117  min.
#
#
# Count;  120  Image Name:  20008
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  175.02980709473292  min.
#
#
# Count;  121  Image Name:  202012
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  176.54149947563806  min.
#
#
# Count;  122  Image Name:  207056
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  177.8145770629247  min.
#
#
# Count;  123  Image Name:  208001
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  179.32053359746934  min.
#
#
# Count;  124  Image Name:  209070
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  181.12560190359753  min.
#
#
# Count;  125  Image Name:  2092
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  182.58740901947021  min.
#
#
# Count;  126  Image Name:  210088
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  185.42169311443965  min.
#
#
# Count;  127  Image Name:  21077
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  186.92542429367703  min.
#
#
# Count;  128  Image Name:  216041
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  188.3002371629079  min.
#
#
# Count;  129  Image Name:  216053
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  189.67284671465555  min.
#
#
# Count;  130  Image Name:  216066
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  191.22019199927647  min.
#
#
# Count;  131  Image Name:  216081
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  192.9441276550293  min.
#
#
# Count;  132  Image Name:  219090
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  194.32553829352062  min.
#
#
# Count;  133  Image Name:  220075
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  195.86426329215368  min.
#
#
# Count;  134  Image Name:  22013
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  197.51222289800643  min.
#
#
# Count;  135  Image Name:  22090
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  198.90011800527571  min.
#
#
# Count;  136  Image Name:  22093
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  200.3749778866768  min.
#
#
# Count;  137  Image Name:  223061
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  201.70197379191717  min.
#
#
# Count;  138  Image Name:  225017
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  203.06860202550888  min.
#
#
# Count;  139  Image Name:  227040
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  204.449990884463  min.
#
#
# Count;  140  Image Name:  227046
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  205.89726972182592  min.
#
#
# Count;  141  Image Name:  227092
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  207.1839096148809  min.
#
#
# Count;  142  Image Name:  229036
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  208.65633797248205  min.
#
#
# Count;  143  Image Name:  23025
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  210.08939141432444  min.
#
#
# Count;  144  Image Name:  23080
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  211.54344354867936  min.
#
#
# Count;  145  Image Name:  23084
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  213.01198401848475  min.
#
#
# Count;  146  Image Name:  231015
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  214.62671282291413  min.
#
#
# Count;  147  Image Name:  232038
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  215.9939047932625  min.
#
#
# Count;  148  Image Name:  236017
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  217.38270409901938  min.
#
#
# Count;  149  Image Name:  236037
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  218.76396776040394  min.
#
#
# Count;  150  Image Name:  238011
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  220.02975966135662  min.
#
#
# Count;  151  Image Name:  239007
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# Failed for image# :  151   239007
#
# Count;  152  Image Name:  239096
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  222.55710065762202  min.
#
#
# Count;  153  Image Name:  24004
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  224.04141352176666  min.
#
#
# Count;  154  Image Name:  24063
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  225.46140862305958  min.
#
#
# Count;  155  Image Name:  24077
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  227.15309629440307  min.
#
#
# Count;  156  Image Name:  241004
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  228.4764616449674  min.
#
#
# Count;  157  Image Name:  241048
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  229.95917029778164  min.
#
#
# Count;  158  Image Name:  242078
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  231.82163054943084  min.
#
#
# Count;  159  Image Name:  245051
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  233.2580237666766  min.
#
#
# Count;  160  Image Name:  246016
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  234.69963857332866  min.
#
#
# Count;  161  Image Name:  246053
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  236.0319581826528  min.
#
#
# Count;  162  Image Name:  247085
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  237.39957253138223  min.
#
#
# Count;  163  Image Name:  249061
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  238.79092013438543  min.
#
#
# Count;  164  Image Name:  249087
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  240.23742626110712  min.
#
#
# Count;  165  Image Name:  25098
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  242.05309729178745  min.
#
#
# Count;  166  Image Name:  253027
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  243.4183761994044  min.
#
#
# Count;  167  Image Name:  253036
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  244.67926474412283  min.
#
#
# Count;  168  Image Name:  253055
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  246.02881179650623  min.
#
#
# Count;  169  Image Name:  254033
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  247.40839347839355  min.
#
#
# Count;  170  Image Name:  254054
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  248.77323380708694  min.
#
#
# Count;  171  Image Name:  260058
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  250.0544630964597  min.
#
#
# Count;  172  Image Name:  260081
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  251.61168677806853  min.
#
#
# Count;  173  Image Name:  26031
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  252.87815780242283  min.
#
#
# Count;  174  Image Name:  268002
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  254.20983779827753  min.
#
#
# Count;  175  Image Name:  27059
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  255.61007338762283  min.
#
#
# Count;  176  Image Name:  271008
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  257.0407547434171  min.
#
#
# Count;  177  Image Name:  271031
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  258.24779946804045  min.
#
#
# Count;  178  Image Name:  271035
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  259.90979016621907  min.
#
#
# Count;  179  Image Name:  274007
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  261.33929152091343  min.
#
#
# Count;  180  Image Name:  277095
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  262.78367537260056  min.
#
#
# Count;  181  Image Name:  28075
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  264.14550313552223  min.
#
#
# Count;  182  Image Name:  28096
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  265.3523871143659  min.
#
#
# Count;  183  Image Name:  285036
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  266.7914416313171  min.
#
#
# Count;  184  Image Name:  285079
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  268.4072110255559  min.
#
#
# Count;  185  Image Name:  286092
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  269.7916473865509  min.
#
#
# Count;  186  Image Name:  291000
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  271.07484872341155  min.
#
#
# Count;  187  Image Name:  292066
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  272.56727952162424  min.
#
#
# Count;  188  Image Name:  293029
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  273.95529989798865  min.
#
#
# Count;  189  Image Name:  295087
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  275.300650036335  min.
#
#
# Count;  190  Image Name:  296007
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  276.69324657917025  min.
#
#
# Count;  191  Image Name:  296059
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  278.0843668023745  min.
#
#
# Count;  192  Image Name:  299086
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  279.38494786421455  min.
#
#
# Count;  193  Image Name:  299091
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  280.7027313152949  min.
#
#
# Count;  194  Image Name:  300091
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  282.0254637678464  min.
#
#
# Count;  195  Image Name:  301007
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  283.4212702592214  min.
#
#
# Count;  196  Image Name:  302003
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  285.01087304751076  min.
#
#
# Count;  197  Image Name:  302008
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  286.4610395828883  min.
#
#
# Count;  198  Image Name:  304034
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  288.01190984249115  min.
#
#
# Count;  199  Image Name:  304074
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  289.39795822699864  min.
#
#
# Count;  200  Image Name:  306005
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  290.98543373743695  min.
#
#
# Count;  201  Image Name:  309004
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  292.3593714118004  min.
#
#
# Count;  202  Image Name:  3096
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  293.5976668278376  min.
#
#
# Count;  203  Image Name:  310007
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  294.9994156797727  min.
#
#
# Count;  204  Image Name:  311068
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  296.4085057258606  min.
#
#
# Count;  205  Image Name:  311081
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  297.9095299522082  min.
#
#
# Count;  206  Image Name:  314016
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  299.2717350721359  min.
#
#
# Count;  207  Image Name:  317080
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  300.7859007716179  min.
#
#
# Count;  208  Image Name:  323016
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  302.33334619601567  min.
#
#
# Count;  209  Image Name:  326038
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  303.6054184953372  min.
#
#
# Count;  210  Image Name:  33039
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# Failed for image# :  210   33039
#
# Count;  211  Image Name:  33066
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  306.3154952764511  min.
#
#
# Count;  212  Image Name:  35008
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  307.919797372818  min.
#
#
# Count;  213  Image Name:  35010
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  309.69496610959374  min.
#
#
# Count;  214  Image Name:  35058
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  311.0038786451022  min.
#
#
# Count;  215  Image Name:  35070
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  312.33289103507997  min.
#
#
# Count;  216  Image Name:  35091
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  313.99120527505875  min.
#
#
# Count;  217  Image Name:  351093
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  315.42681821187335  min.
#
#
# Count;  218  Image Name:  353013
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  316.8713086803754  min.
#
#
# Count;  219  Image Name:  361010
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  318.49434185822804  min.
#
#
# Count;  220  Image Name:  361084
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  320.2043483734131  min.
#
#
# Count;  221  Image Name:  365025
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  321.76626073122026  min.
#
#
# Count;  222  Image Name:  365073
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  323.35621180136997  min.
#
#
# Count;  223  Image Name:  368016
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  324.9179475347201  min.
#
#
# Count;  224  Image Name:  368078
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  326.487236169974  min.
#
#
# Count;  225  Image Name:  370036
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  328.26926436424253  min.
#
#
# Count;  226  Image Name:  37073
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  329.88542579809825  min.
#
#
# Count;  227  Image Name:  372047
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  331.5950543721517  min.
#
#
# Count;  228  Image Name:  374020
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  333.27328681151073  min.
#
#
# Count;  229  Image Name:  374067
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  334.66198596556984  min.
#
#
# Count;  230  Image Name:  376001
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# Failed for image# :  230   376001
#
# Count;  231  Image Name:  376020
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  337.2345223267873  min.
#
#
# Count;  232  Image Name:  376043
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  338.8665276646614  min.
#
#
# Count;  233  Image Name:  38082
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  340.479508348306  min.
#
#
# Count;  234  Image Name:  38092
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  342.0793055812518  min.
#
#
# Count;  235  Image Name:  385028
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  343.5823664625486  min.
#
#
# Count;  236  Image Name:  385039
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  345.21658484141034  min.
#
#
# Count;  237  Image Name:  388016
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  347.0539476156235  min.
#
#
# Count;  238  Image Name:  41004
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  348.35777275164924  min.
#
#
# Count;  239  Image Name:  41025
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  349.75514096419016  min.
#
#
# Count;  240  Image Name:  41033
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  351.1934176921844  min.
#
#
# Count;  241  Image Name:  41069
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  352.5783202091853  min.
#
#
# Count;  242  Image Name:  42012
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  354.14409615596134  min.
#
#
# Count;  243  Image Name:  42044
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  355.55344018538796  min.
#
#
# Count;  244  Image Name:  42049
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  356.9614982088407  min.
#
#
# Count;  245  Image Name:  42078
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  358.34226905504863  min.
#
#
# Count;  246  Image Name:  43070
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  359.6560553471247  min.
#
#
# Count;  247  Image Name:  43074
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  360.9864197532336  min.
#
#
# Count;  248  Image Name:  43083
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  362.49343246618906  min.
#
#
# Count;  249  Image Name:  45077
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  363.98014074166616  min.
#
#
# Count;  250  Image Name:  45096
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  365.3483105421066  min.
#
#
# Count;  251  Image Name:  46076
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  366.69750421444576  min.
#
#
# Count;  252  Image Name:  48055
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  368.03457239071525  min.
#
#
# Count;  253  Image Name:  54005
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  369.4522266864777  min.
#
#
# Count;  254  Image Name:  54082
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  370.85167409181594  min.
#
#
# Count;  255  Image Name:  55067
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  372.191146449248  min.
#
#
# Count;  256  Image Name:  55073
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  373.68033150434496  min.
#
#
# Count;  257  Image Name:  55075
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  375.13830687999723  min.
#
#
# Count;  258  Image Name:  56028
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  377.03384646972023  min.
#
#
# Count;  259  Image Name:  58060
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  378.48842244942983  min.
#
#
# Count;  260  Image Name:  59078
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  379.9318896770477  min.
#
#
# Count;  261  Image Name:  60079
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  381.14724778731664  min.
#
#
# Count;  262  Image Name:  61060
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  382.53576314051946  min.
#
#
# Count;  263  Image Name:  61086
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  384.1846038222313  min.
#
#
# Count;  264  Image Name:  62096
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  385.5335981329282  min.
#
#
# Count;  265  Image Name:  65010
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  387.0335718750954  min.
#
#
# Count;  266  Image Name:  65019
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# Failed for image# :  266   65019
#
# Count;  267  Image Name:  65033
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  389.56184228658674  min.
#
#
# Count;  268  Image Name:  65074
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  391.09390927553176  min.
#
#
# Count;  269  Image Name:  65132
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  392.62203321854275  min.
#
#
# Count;  270  Image Name:  66039
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  393.98032369613645  min.
#
#
# Count;  271  Image Name:  66053
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  395.43922233978907  min.
#
#
# Count;  272  Image Name:  66075
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  396.7357303579648  min.
#
#
# Count;  273  Image Name:  67079
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  398.3842314243317  min.
#
#
# Count;  274  Image Name:  68077
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  399.804716304938  min.
#
#
# Count;  275  Image Name:  69015
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  401.34763658444086  min.
#
#
# Count;  276  Image Name:  69020
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  402.77944549322126  min.
#
#
# Count;  277  Image Name:  69040
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  404.05048525333405  min.
#
#
# Count;  278  Image Name:  71046
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  405.3991416414579  min.
#
#
# Count;  279  Image Name:  76002
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  406.7774723728498  min.
#
#
# Count;  280  Image Name:  76053
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  408.24749105771383  min.
#
#
# Count;  281  Image Name:  78004
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  409.7027572989464  min.
#
#
# Count;  282  Image Name:  78019
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  411.23261458476384  min.
#
#
# Count;  283  Image Name:  80099
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  412.4487205664317  min.
#
#
# Count;  284  Image Name:  8023
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  413.72889804442724  min.
#
#
# Count;  285  Image Name:  8049
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  415.1048464854558  min.
#
#
# Count;  286  Image Name:  8143
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  416.4931948105494  min.
#
#
# Count;  287  Image Name:  85048
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  418.42759705781936  min.
#
#
# Count;  288  Image Name:  86000
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  420.0131642460823  min.
#
#
# Count;  289  Image Name:  86016
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  421.4128815134366  min.
#
#
# Count;  290  Image Name:  86068
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  422.6559875766436  min.
#
#
# Count;  291  Image Name:  87046
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  424.2323604106903  min.
#
#
# Count;  292  Image Name:  87065
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  426.5784174760183  min.
#
#
# Count;  293  Image Name:  89072
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  428.0299552877744  min.
#
#
# Count;  294  Image Name:  90076
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  429.3870288093885  min.
#
#
# Count;  295  Image Name:  92059
# (481, 321, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  430.8135560830434  min.
#
#
# Count;  296  Image Name:  94079
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  432.2730939467748  min.
#
#
# Count;  297  Image Name:  95006
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  433.65372371673584  min.
#
#
# Count;  298  Image Name:  97017
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  435.1214653333028  min.
#
#
# Count;  299  Image Name:  97033
# (321, 481, 3)
# running LSC
# running SLIC
# running NormCut
# running FH
# running SEEDS
#
# Total Elapsed Time so far...:  436.5747039914131  min.

# %% [markdown]
# ## Take average over multiple runs (i.e., multiple images)

# %%
average_runtime_LSC = None 
average_runtime_SLIC = None 
average_runtime_NormCut = None 
average_runtime_FH = None
average_runtime_SEEDS = None


def list_avg(lst):
    
    lim = 20
    
    b = [0 for x in range(len(lst[0]))]

    for i in range(len(b)):
        s = 0
        for j in range(len(lst[:lim])):
            s += lst[j][i]
            
        b[i] = s/len(lst[:lim])
     
    return b


if doLSC:
    average_runtime_LSC = list_avg(collect_runtime_LSC)
    average_UE_LSC = list_avg(collect_UE_LSC)
    average_BR_LSC = list_avg(collect_BR_LSC)

if doSLIC:
    average_runtime_SLIC = list_avg(collect_runtime_SLIC)
    average_UE_SLIC = list_avg(collect_UE_SLIC)
    average_BR_SLIC = list_avg(collect_BR_SLIC)

if doNormCut:
    average_runtime_NormCut = list_avg(collect_runtime_NormCut)
    average_UE_NormCut = list_avg(collect_UE_NormCut)
    average_BR_NormCut = list_avg(collect_BR_NormCut)

if doFH:
    average_runtime_FH = list_avg(collect_runtime_FH)
    average_UE_FH = list_avg(collect_UE_FH)
    average_BR_FH = list_avg(collect_BR_FH)
    
    
if doSEEDS:
    average_runtime_SEEDS = list_avg(collect_runtime_SEEDS)
    average_UE_SEEDS = list_avg(collect_UE_SEEDS)
    average_BR_SEEDS = list_avg(collect_BR_SEEDS)

# %% [markdown]
# ## Plot Results

# %%
def plot_metrics(for_LSC, for_SLIC, for_NormCut, for_FH, for_SEEDS):
    lgnd = []

    if for_LSC:
        plt.plot(n_superpixels, for_LSC, 's-')
        lgnd.append('LSC')

    if for_SLIC:
        plt.plot(n_superpixels, for_SLIC, '*-')
        lgnd.append('SLIC')

    if for_NormCut:
        plt.plot(n_superpixels, for_NormCut, '^-')
        lgnd.append('Normalized Cut')

    if for_FH:
        plt.plot(n_superpixels, for_FH, '+-')
        lgnd.append('Felzenszwalb')

        
    if for_SEEDS:
        plt.plot(n_superpixels, for_SEEDS, 'D-')
        lgnd.append('SEEDS')
        
        
    return lgnd

# %%
fs = 20

# %%
clear_output()

plt.figure(figsize=(18, 10))
plt.title("Runtime (in sec)", fontsize=fs, y=1.1, fontweight='bold')

lgnd = plot_metrics(average_runtime_LSC, average_runtime_SLIC, average_runtime_NormCut, average_runtime_FH, 
                    average_runtime_SEEDS)

plt.legend(lgnd, loc='upper left', prop={'size': 15})
plt.xlabel('Number of Segments (approximate)', fontsize=15)
plt.ylabel('Time in Seconds', fontsize=15)

plt.show()

# %%
clear_output()

plt.figure(figsize=(18, 10))
plt.title("Runtime (in sec), plot w/o Norm Cut", fontsize=fs, y=1.1, fontweight='bold')

lgnd = plot_metrics(average_runtime_LSC, average_runtime_SLIC, None, average_runtime_FH, 
                    average_runtime_SEEDS)

plt.legend(lgnd, loc='upper left', prop={'size': 15})
plt.xlabel('Number of Segments (approximate)', fontsize=15)
plt.ylabel('Time in Seconds', fontsize=15)

plt.show()

# %%
clear_output()

plt.figure(figsize=(18, 10))
plt.title("Undersegmentation Error", fontsize=fs, y=1.1, fontweight='bold')

lgnd = plot_metrics(average_UE_LSC, average_UE_SLIC, average_UE_NormCut, average_UE_FH, average_UE_SEEDS)

plt.legend(lgnd, loc='upper right', prop={'size': 15})
plt.xlabel('Number of Segments (approximate)', fontsize=15)
plt.ylabel('Undersegmentation Error: Fraction of Leaking Superpixels', fontsize=15)

plt.show()

# %%
clear_output()

plt.figure(figsize=(18, 10))
plt.title("Boundary Recall", fontsize=fs, y=1.1, fontweight='bold')

lgnd = plot_metrics(average_BR_LSC, average_BR_SLIC, average_BR_NormCut, average_BR_FH, average_BR_SEEDS)

plt.legend(lgnd, loc='upper left', prop={'size': 15})
plt.xlabel('Number of Segments (approximate)', fontsize=15)
plt.ylabel('Boundary Recall fraction', fontsize=15)

plt.show()
